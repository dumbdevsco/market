# %%
import StorePerek2
StorePerek2.tsv_update_shortcards('agody')

# %%
import StorePerek2
StorePerek2.tsv_update_shortcards_all()
# Out:
# moloko
# syr
# tvorog
# syrki
# jogurty
# tvorozki
# deserty-i-sneki
# ajca
# maslo
# margarin
# spred
# kislomolocnye-produkty
# smetana
# slivki
# molocnye-konservy
# molocnye-koktejli
# ovosi
# frukty
# agody
# zelen-i-salaty
# griby
# solena
# makarony
# rastitelnoe-maslo
# krupy
# bobovye
# specii-pripravy-i-pranosti
# muka
# komponenty-dla-vypecki
# sol
# cipsy
# nacos
# sneki
# popkorn
# suhariki
# grenki
# kukuruznye-palocki
# suski-i-baranki
# solomki
# hlebnye-palocki
# suhari
# hlebcy
# vodorosli
# pecene
# vafli
# praniki
# sokolad
# batonciki
# sokoladnye-i-orehovye-pasty
# konfety
# torty
# piroznye
# pirogi-sdoba-keksy-rulety
# zefir
# marmelad
# pastila
# diabeticeskie-sladosti
# ledency
# draze
# vostocnye-sladosti-halva
# zevatelnaa-rezinka
# morozenoe
# voda
# gazirovannye-napitki
# soki
# nektary
# kvas
# holodnyj-caj
# rastitelnye-napitki
# bezalkogolnoe-vino
# bezalkogolnoe-pivo
# sokosoderzasie-napitki
# smuzi
# energeticeskie-napitki
# morsy
# kiseli
# ...

# %%
import StorePerek2
StorePerek2.tsv_update_fullcards('agody')

# %%
import StorePerek2
StorePerek2.tsv_update_fullcards_all()
# Out:
# moloko
# syr
# tvorog
# syrki
# jogurty
# https://www.perekrestok.ru/cat/119/p/produkt-jogurtnyj-fruttis-slivocnoe-lakomstvo-dyna-mango-banan-klubnika-5-115g-3421276
# https://www.perekrestok.ru/cat/119/p/biojogurt-carka-6-400g-3495771
# https://www.perekrestok.ru/cat/119/p/jogurt-carka-persik-marakuja-3-5-400g-3495776
# https://www.perekrestok.ru/cat/119/p/produkt-jogurtnyj-fruttis-klubnika-persik-5-115g-2062718
# https://www.perekrestok.ru/cat/119/p/produkt-jogurtnyj-ermigurt-klubnika-zemlanika-7-5-100g-3969345
# https://www.perekrestok.ru/cat/119/p/produkt-jogurtnyj-ermigurt-tropiceskie-frukty-7-5-100g-3969344
# https://www.perekrestok.ru/cat/119/p/jogurt-kolomenskij-klubnika-banan-5-170g-4198734
# https://www.perekrestok.ru/cat/119/p/jogurt-kolomenskij-mango-5-170g-4198733
# https://www.perekrestok.ru/cat/119/p/jogurt-molocnaa-kultura-s-golubikoj-ezevikoj-i-granoloj-s-izumom-2-7-3-5-190g-4262902
# https://www.perekrestok.ru/cat/119/p/jogurt-kirzacskij-zemlanika-2-5-315g-4324262
# ...

# %%
import StorePerek2
StorePerek2.tsv_find_duplicates('jogurty')
# Out:
# {}

# %%
import StorePerek2
bro = StorePerek2.get_browser_local('pg')
bro.get(StorePerek2.get_cat_url('moloko'))
cards = StorePerek2.parse_shortcards(bro.page_source)
cards
# Out:
# улица Малыгина, 5
# [{'name': 'Молоко Простоквашино пастеризованное 2.5%, 930мл',
#   'price': '74,99\xa0₽/шт',
#   'size': '930 мл',
#   'url': 'https://www.perekrestok.ru/cat/114/p/moloko-prostokvasino-pasterizovannoe-2-5-930ml-2093081',
#   'time': 'Sun Jul  7 13:31:43 2024',
#   'name_': 'none',
#   'price_': 'none',
#   'brand': 'none',
#   'calories': 'none',
#   'proteins': 'none',
#   'fats': 'none',
#   'carbos': 'none',
#   'composition': 'none',
#   'get_ok': 'none',
#   'parse_ok': 'none',
#   'time_': 'none'},
#  {'name': 'Молоко Простоквашино отборное пастеризованное 3.4-4.5%, 930мл',
#   'price': '89,99\xa0₽/шт',
#   'size': '930 мл',
#   'url': 'https://www.perekrestok.ru/cat/114/p/moloko-prostokvasino-otbornoe-pasterizovannoe-3-4-4-5-930ml-2085981',
#   'time': 'Sun Jul  7 13:31:43 2024',
#   'name_': 'none',
#   'price_': 'none',
#   'brand': 'none',
#   'calories': 'none',
#   'proteins': 'none',
#   'fats': 'none',
#   'carbos': 'none',
#   'composition': 'none',
# ...

# %%
import StorePerek2
StorePerek2.tsv_update_shortcards_local('spb')
# Out:
# Биржевая площадь, 4
# moloko
# syr
# tvorog
# syrki
# jogurty
# tvorozki
# deserty-i-sneki
# ajca
# maslo
# margarin
# spred
# kislomolocnye-produkty
# smetana
# slivki
# molocnye-konservy
# molocnye-koktejli
# ovosi
# frukty
# agody
# zelen-i-salaty
# griby
# solena
# makarony
# rastitelnoe-maslo
# krupy
# bobovye
# specii-pripravy-i-pranosti
# muka
# komponenty-dla-vypecki
# sol
# cipsy
# nacos
# sneki
# popkorn
# suhariki
# grenki
# kukuruznye-palocki
# suski-i-baranki
# solomki
# hlebnye-palocki
# suhari
# hlebcy
# vodorosli
# pecene
# vafli
# praniki
# sokolad
# batonciki
# sokoladnye-i-orehovye-pasty
# konfety
# torty
# piroznye
# pirogi-sdoba-keksy-rulety
# zefir
# marmelad
# pastila
# diabeticeskie-sladosti
# ledency
# draze
# vostocnye-sladosti-halva
# zevatelnaa-rezinka
# morozenoe
# voda
# gazirovannye-napitki
# soki
# nektary
# kvas
# holodnyj-caj
# rastitelnye-napitki
# bezalkogolnoe-vino
# bezalkogolnoe-pivo
# sokosoderzasie-napitki
# smuzi
# energeticeskie-napitki
# ...

# %%
import StorePerek2

StorePerek2.tsv_update_prices_local('moloko', 'rnd')

# %%
import StorePerek2
StorePerek2.all_update()
# Out:
# Большой Патриарший переулок, 5
# moloko
# syr
# tvorog
# syrki
# jogurty
# tvorozki
# deserty-i-sneki
# ajca
# maslo
# margarin
# spred
# kislomolocnye-produkty
# smetana
# slivki
# molocnye-konservy
# molocnye-koktejli
# ovosi
# frukty
# agody
# zelen-i-salaty
# griby
# solena
# makarony
# rastitelnoe-maslo
# krupy
# bobovye
# specii-pripravy-i-pranosti
# muka
# komponenty-dla-vypecki
# sol
# cipsy
# nacos
# sneki
# popkorn
# suhariki
# grenki
# kukuruznye-palocki
# suski-i-baranki
# solomki
# hlebnye-palocki
# suhari
# hlebcy
# vodorosli
# pecene
# vafli
# praniki
# sokolad
# batonciki
# sokoladnye-i-orehovye-pasty
# konfety
# torty
# piroznye
# pirogi-sdoba-keksy-rulety
# zefir
# marmelad
# pastila
# diabeticeskie-sladosti
# ledency
# draze
# vostocnye-sladosti-halva
# zevatelnaa-rezinka
# morozenoe
# voda
# gazirovannye-napitki
# soki
# nektary
# kvas
# holodnyj-caj
# rastitelnye-napitki
# bezalkogolnoe-vino
# bezalkogolnoe-pivo
# sokosoderzasie-napitki
# smuzi
# ...

# %%
import StorePerek2
import datetime
StorePerek2.tsv_set_column_price('time', datetime.datetime.now().ctime())
# Out:
# ../market-data/perekrestok/price/2024-07-07/masnye-konservy.tsv
# ../market-data/perekrestok/price/2024-07-07/vermut.tsv
# ../market-data/perekrestok/price/2024-07-07/griby.tsv
# ../market-data/perekrestok/price/2024-07-07/suhofrukty.tsv
# ../market-data/perekrestok/price/2024-07-07/margarin.tsv
# ../market-data/perekrestok/price/2024-07-07/diabeticeskie-sladosti.tsv
# ../market-data/perekrestok/price/2024-07-07/praniki.tsv
# ../market-data/perekrestok/price/2024-07-07/krabovoe-maso-i-palocki.tsv
# ../market-data/perekrestok/price/2024-07-07/pecene.tsv
# ../market-data/perekrestok/price/2024-07-07/koktejli-iz-moreproduktov.tsv
# ../market-data/perekrestok/price/2024-07-07/zamorozennaa-ryba.tsv
# ../market-data/perekrestok/price/2024-07-07/suski-i-baranki.tsv
# ../market-data/perekrestok/price/2024-07-07/orehi.tsv
# ../market-data/perekrestok/price/2024-07-07/ikra.tsv
# ../market-data/perekrestok/price/2024-07-07/torty.tsv
# ../market-data/perekrestok/price/2024-07-07/hlebcy.tsv
# ...

# %%
import StorePerek2
StorePerek2.tsv_update_prices_local('moloko', 'spb')
